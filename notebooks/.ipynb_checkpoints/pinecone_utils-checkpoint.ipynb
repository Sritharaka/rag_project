# %%
# pinecone_utils.py
import os
import sys
sys.path.append(os.getcwd())  # Makes sure current folder is in path


from pinecone import Pinecone, ServerlessSpec
from config import PINECONE_API_KEY, PINECONE_ENVIRONMENT, PINECONE_INDEX_NAME, VECTOR_DIM

def init_pinecone():
    pc = Pinecone(api_key=PINECONE_API_KEY)

    # Extract region from PINECONE_ENVIRONMENT like 'gcp-starter' -> 'starter'
    region = PINECONE_ENVIRONMENT.split("-")[-1]
    cloud = PINECONE_ENVIRONMENT.split("-")[0]

    # Create index if it doesn't exist
    if PINECONE_INDEX_NAME not in pc.list_indexes().names():
        pc.create_index(
            name=PINECONE_INDEX_NAME,
            dimension=VECTOR_DIM,
            metric="cosine",
            spec=ServerlessSpec(cloud=cloud, region=region)
        )

    return pc.Index(PINECONE_INDEX_NAME)

def upsert_vectors(index, vectors):
    index.upsert(vectors=vectors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 6
#       3 import sys
#       5 # ✅ Ensure current script directory is in the Python path
# ----> 6 sys.path.append(os.path.dirname(os.path.abspath(__file__)))
#       8 from pinecone import Pinecone, ServerlessSpec
#       9 from config import PINECONE_API_KEY, PINECONE_ENVIRONMENT, PINECONE_INDEX_NAME, VECTOR_DIM
#
# NameError: name '__file__' is not defined
